# %%
import ibis
from ibis import _
import polars as pl
import pandas as pd
import holoviews as hv
import easier as ezr
import maidenhead
hv.extension('bokeh')
from hvplot import pandas
from geopy.distance import geodesic as GD
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1004'>
#   <div id="c968e66d-c329-4101-92fc-d224d8158867" data-root-id="p1004" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
class Loader:
    @ezr.cached_container
    def df(self):
        t = ibis.read_csv('./data/20230310T060000.tsv.gz')
        t = t.head(100000)
        
        df = t.execute()
        
        # df = df.head(100000)
        df = df[df['mode'] == 'FT8']
        df['num_recs'] = 1
        df['seconds'] = (15*(((df.flowStartSeconds + 5) % 60) // 15))
        df['minutes'] = 60 * (df.flowStartSeconds // 60)
        df['nominal_time'] = df.minutes + df.seconds
        df['timestamp'] = ezr.pandas_utc_seconds_to_time(df.flowStartSeconds)
        df.columns = ezr.slugify(df.columns, kill_camel=True)
        df = df[['timestamp', 'frequency', 'sender_callsign', 'receiver_callsign', 'sender_locator', 'receiver_locator']]
        
        s = df.sender_callsign.value_counts()
        s = s[s >= 100]
        df = df[df.sender_callsign.isin(s.index)]
        
        
        df = df[pd.notnull(df.receiver_locator)]
        df = df[df.receiver_locator.str.len().between(2, 8)]
        df = df[df.receiver_locator.str.len() % 2 == 0]
        
        df = df[pd.notnull(df.sender_locator)]
        df = df[df.sender_locator.str.len().between(2, 8)]
        df = df[df.sender_locator.str.len() % 2 == 0]
        
        df = df.join(pd.DataFrame(list(df.sender_locator.apply(maidenhead.to_location)), columns=['lat_s', 'lon_s'], index = df.index), how='inner')
        df = df.join(pd.DataFrame(list(df.receiver_locator.apply(maidenhead.to_location)), columns=['lat_r', 'lon_r'], index = df.index), how='inner')
        df['epoch'] = df.timestamp.dt.floor('1h')
        df['num_spots'] = 1  
        return df
loader = Loader()

# %%
df = loader.df
df.head()
# Out:
#             timestamp  frequency sender_callsign receiver_callsign  \
# 1 2023-03-09 23:42:11   14075157            KE6V            WA5VAH
# 3 2023-03-09 23:42:12   14075835           W8ATE            WA5VAH
# 4 2023-03-09 23:42:12   14076221           NY6DX            WA5VAH
# 5 2023-03-09 23:42:12   14075997           W3YNI            WA5VAH
# 6 2023-03-09 23:42:12   14074404           W2GLH            WA5VAH
#
#   sender_locator receiver_locator  lat_s  lon_s      lat_r  lon_r  \
# 1           DM13           DN13SO   33.0 -118.0  43.583333 -116.5
# 3           EN81           DN13SO   41.0  -84.0  43.583333 -116.5
# 4           FN30           DN13SO   40.0  -74.0  43.583333 -116.5
# 5           FN00           DN13SO   40.0  -80.0  43.583333 -116.5
# 6           FM29           DN13SO   39.0  -76.0  43.583333 -116.5
#
#                 epoch  num_spots
# 1 2023-03-09 23:00:00          1
# 3 2023-03-09 23:00:00          1
# 4 2023-03-09 23:00:00          1
# ...

# %%
df_list = []
def doit(batch):
    batch = batch.drop_duplicates(['receiver_callsign'])
    if len(batch) < 5:
        return batch

    dfr = batch[['lat_r', 'lon_r', 'num_spots']].rename(columns={'lat_r': 'lat', 'lon_r': 'lon'})

    dfd = pd.merge(dfr, dfr, on='num_spots', suffixes=['_1', '_2'])
    dfd['dist'] = [GD((lat1, lon1), (lat2, lon2)).mi for (lat1, lon1, lat2, lon2) in zip(dfd.lat_1, dfd.lon_1, dfd.lat_2, dfd.lon_2)]
    df_list.append(dfd[['dist']])
    return batch

df = loader.df.head(10000)
df.groupby(by=['sender_callsign', 'epoch'], group_keys=False).apply(doit);
dfd = pd.concat(df_list, axis=0, ignore_index=True, sort=False)
dfd

# %%
dfd.dist.hvplot.hist(bins=100)
# Out:
# :Histogram   [dist]   (dist_count)

# %%
df.groupby(by=['nominal_time', 'senderCallsign'])['num_recs'].sum().reset_index().groupby(by=['senderCallsign'])[['num_recs']].mean().hvplot.hist(bin_range=(1.1, 60), bins=200)
# Out:
# :Histogram   [num_recs]   (num_recs_count)

# %%
df.groupby(by=['nominal_time', 'senderCallsign'])['snr'].mean().reset_index().groupby(by=['senderCallsign'])[['snr']].mean().hvplot.hist(bin_range=(-30, 30), bins=200)
# Out:
# :Histogram   [snr]   (snr_count)

# %%
dfx_ = df[df.senderCallsign == 'KF9UG']
dfx = dfx.copy()

# %%
dfx = dfx_.copy()
dfx = dfx[pd.notnull(dfx.receiverLocator)]
dfx = dfx[dfx.receiverLocator.str.len().between(2, 8)]
dfx = dfx[dfx.receiverLocator.str.len() % 2 == 0]

dfx = dfx.join(pd.DataFrame(list(dfx.receiverLocator.apply(maidenhead.to_location)), columns=['lat', 'lon'], index = dfx.index), how='inner')
mean_snr = dfx.groupby(by='nominal_time')[['snr']].mean().reset_index().rename(columns={'snr': 'mean_snr'})
dfx = pd.merge(dfx, mean_snr, on='nominal_time')
dfx['snr_anomoly'] = dfx.snr - dfx.mean_snr
dfx['lat_bin'] = 2 * (dfx.lat // 2)
dfx['lon_bin'] = 2 * (dfx.lon // 2)
c = 299792458
dfx['wavelength'] = (c / dfx.frequency).round()
dfx = dfx[dfx.wavelength==21.]
dfx
# Out:
#        flowStartSeconds   frequency   snr mode senderCallsign senderLocator  \
# 8126         1678406741  14075672.0   2.0  FT8          KF9UG          EN71
# 8211         1678406771  14075673.0   3.0  FT8          KF9UG          EN71
# 8547         1678406861  14075674.0  -8.0  FT8          KF9UG          EN71
# 8699         1678406891  14075672.0  -3.0  FT8          KF9UG          EN71
# 10244        1678407387  14075663.0  -4.0  FT8          KF9UG          EN71
# ...                 ...         ...   ...  ...            ...           ...
# 96242        1678427982  14075592.0 -13.0  FT8          KF9UG          EN71
# 96244        1678427981  14075591.0   4.0  FT8          KF9UG          EN71
# 96246        1678427982  14075597.0 -17.0  FT8          KF9UG          EN71
# 96249        1678427982  14075593.0  12.0  FT8          KF9UG          EN71
# 96252        1678427970  14075579.0 -14.0  FT8          KF9UG          None
#
# ...

# %%
from geopy.distance import geodesic as GD
for t, batch in dfx.groupby(by='nominal_time'):
    if len(batch) < 100:
        continue
    batch = batch[['receiverCallsign', 'lat', 'lon']].copy()
    batch_orig = batch.copy()
    batch['dummy'] = 1
    batch = pd.merge(batch, batch, on='dummy', suffixes=['_1', '_2'])
    batch['qso'] = [set(t) for t in zip(batch.receiverCallsign_1, batch.receiverCallsign_2)]
    batch = batch[[(len(qso) > 1) for qso in batch.qso]]
    batch = batch.drop_duplicates(subset=['qso'])
    batch['dist'] = [GD((lat1, lon1), (lat2, lon2)).mi for (lat1, lon1, lat2, lon2) in zip(batch.lat_1, batch.lon_1, batch.lat_2, batch.lon_2)]
    break
# batch = pd.concat(batch_list, axis=0, ignore_index=True, sort=False)
batch
# Out:
#       receiverCallsign_1      lat_1       lon_1  dummy receiverCallsign_2  \
# 1                 KC2VKD  40.750000  -73.833333      1              K4UNK
# 2                 KC2VKD  40.750000  -73.833333      1             WA6LMM
# 3                 KC2VKD  40.750000  -73.833333      1               NR5O
# 4                 KC2VKD  40.750000  -73.833333      1              KE8KW
# 5                 KC2VKD  40.750000  -73.833333      1              KG0ED
# ...                  ...        ...         ...    ...                ...
# 14758             VE7AFV  49.208333 -122.833333      1             IZ3ATV
# 14759             VE7AFV  49.208333 -122.833333      1              NP4JF
# 14881              KC1MA  42.500000  -71.000000      1             IZ3ATV
# 14882              KC1MA  42.500000  -71.000000      1              NP4JF
# 15005             IZ3ATV  45.416667   11.750000      1              NP4JF
#
#            lat_2       lon_2               qso         dist
# ...

# %%
batch_orig.hvplot.scatter('lon', 'lat')
# Out:
# :Scatter   [lon]   (lat)

# %%
ezr.ecdf(batch.dist, N=len(batch), plot=True)
# Out:
# :Curve   [x]   (y)

# %%
import easier as ezr

# %%
import maidenhead
import seaborn as sns

# %%
sns.heatmap(
# sns.heatmap(dfx.head(500), ,
# Out:
# /Users/rob/mambaforge/envs/viz/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
dfx.hvplot.scatter(x='lon_bin', y='lat_bin', c='snr_anomoly')
# Out:
# :Scatter   [lon_bin]   (lat_bin,snr_anomoly)

# %%
dfx
# Out:
#           flowStartSeconds   frequency   snr mode senderCallsign  \
# 800             1678405233  28075669.0 -16.0  FT8          KF9UG
# 8013            1678405081  24917042.0 -15.0  FT8          KF9UG
# 8981            1678405200  28075838.0   3.0  FT8          KF9UG
# 9550            1678405233  28075651.0 -17.0  FT8          KF9UG
# 21418           1678405139  28075673.0 -12.0  FT8          KF9UG
# ...                    ...         ...   ...  ...            ...
# 16573295        1678427982  10137679.0 -18.0  FT8          KF9UG
# 16573417        1678427981  10137679.0  -3.0  FT8          KF9UG
# 16573549        1678427982  14075593.0  12.0  FT8          KF9UG
# 16573858        1678427983  10137687.0 -14.0  FT8          KF9UG
# 16574057        1678427982  10137684.0 -14.0  FT8          KF9UG
#
#          senderLocator receiverCallsign receiverLocator  \
# 800               EN71            VK8AW          PH57mm
# 8013              EN71            VE7OG          CN89kg
# ...
